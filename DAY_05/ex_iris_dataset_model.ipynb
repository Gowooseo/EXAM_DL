# %% [markdown]
# ### Dataset & DataLoader 살펴보기
# - Pytorch에서 배치크기만 데이터를 조절하기 위한 메커니즘
# - Dataset : 사용 데이터를 기반으로 사용자정의 클래스 작성
# - DataLoader : 지정된 Dataset에서 지정된 batch size만큼 피쳐와 타겟을 추출하여 전달

# %% [markdown]
# [1] 모듈 로딩 및 데이터 준비 <hr>

# %%
### ===> 모듈 로딩
import torch 
import torch.nn as nn
from torch.utils.data import Dataset,DataLoader

import numpy as np
import pandas as pd

# %% [markdown]
# - ### [2-2] 사용자 정의 데이터셋 생성

# %%
### 데이터 준비
filename= '../data/irisno.csv'

irisDF=pd.read_csv(filename,header=None,delimiter=',')
irisDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       150 non-null    float64
#  1   1       150 non-null    float64
#  2   2       150 non-null    float64
#  3   3       150 non-null    float64
#  4   4       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
irisNP=np.loadtxt(filename,delimiter=',',usecols=[0,1,2,3])

# %%
irisDF
# Out:
#        0    1    2    3               4
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
###[2-1] 사용자정의 DataSet 클래스
#- 데이터의 텐서 변환
class DLDataset(Dataset):
    
    # 초기화 함수 
    def __init__(self,x_data,y_data):
        super().__init__()
        #x,y 데이터 ==> ndarray
        x_data=x_data.values if isinstance(x_data,pd.DataFrame) else x_data #values는 넘파이로 바꾸어 주는 친구
        y_data=y_data.values if isinstance(y_data,pd.DataFrame) else y_data
        
        #ndarray ==> tensor(데이터 타입이 뭐가 들어올지 몰라서 tensor를 씀)
        self.feature=torch.FloatTensor(x_data)
        self.target=torch.LongTensor(y_data)  #0,1,2(정수)로 라벨 인코더를 사용해 바꿔놨음
        print('[target & target SHAPE]',self.target.shape,self.target.ndim)
        
    #데이터셋의 갯수 체크 함수
    def __len__(self):
        return len(self.target)
        #return self.target.shape[0]
    
    #특정 인덱스 데이터+라벨 반환 콜백함수(callback function)
    def __getitem__(self,index):
        return self.feature[index],self.target[index]  #튜플로 반환

# %%
if irisDF.__class__.__name__=='DataFrame':
    print('DF')
else:
    print('------')
# Out:
# DF

# %%
isinstance(irisDF,pd.DataFrame),isinstance(irisNP,pd.DataFrame)
# Out:
# (True, False)

# %%
isinstance([10],list),isinstance({'A':22},list)
# Out:
# (True, False)

# %% [markdown]
# [2-2]데이터셋 인스턴스 생성

# %%
## 데이터를 feature와 라벨로 분리
featureDF=irisDF[irisDF.columns[:-1]]
targetDF=irisDF[irisDF.columns[-1]].to_frame()  #데이터 프레임화 해서 2차원으로 변경

print(f'featureDF=> {featureDF.shape},{featureDF.ndim}D')
print(f'targetDF=> {targetDF.shape},{targetDF.ndim}D')
# Out:
# featureDF=> (150, 4),2D
# targetDF=> (150, 1),2D

# %%
#object 타입 타겟 ====> int 타입 타겟 변환
from sklearn.preprocessing import LabelEncoder


targetNP=LabelEncoder().fit_transform(targetDF) #넘파이가 됨
targetNP=targetNP.reshape(-1,1) # reshape(-1,1) 뒤에 나오는 1은 행에 있어야 할 개수 그러니까 1을 준건 1개, 밑에 1개 이런식으로 띄워서 쓰기 위한것 그리고 앞에 -1은 그렇게 한줄로 알아서 맞춤으로 만들라는 뜻
#10개라면 ....reshape(-1,2) => 원소,원소
#                             원소,원소
#                             원소,원소


print(f'targetNP=>{targetNP.shape},{targetNP.ndim}D')
# Out:
# targetNP=>(150, 1),2D
# C:\ProgramData\anaconda3\envs\Torch_PY38\lib\site-packages\sklearn\preprocessing\_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
# 데이터셋 생성===> DF,NP
my_dataset=DLDataset(featureDF,targetNP)
my_dataset[0],featureDF.iloc[0],targetDF.iloc[0]
# Out:
# [target & target SHAPE] torch.Size([150, 1]) 2
# ((tensor([5.1000, 3.5000, 1.4000, 0.2000]), tensor([0])),
#  0    5.1
#  1    3.5
#  2    1.4
#  3    0.2
#  Name: 0, dtype: float64,
#  4    Iris-setosa
#  Name: 0, dtype: object)

# %%
# 데이터셋 생성===> NP,NP
my_dataset2=DLDataset(irisNP,targetNP)
my_dataset2[0]
# Out:
# [target & target SHAPE] torch.Size([150, 1]) 2
# (tensor([5.1000, 3.5000, 1.4000, 0.2000]), tensor([0]))

# %% [markdown]
# ### [2-3] 학습용, 검증용, 테스트용(3개로 나누기) Dataset <hr>

# %%
from torch.utils.data import random_split

#학습용,검증용,테스트 데이터 비율
seed=torch.Generator().manual_seed(42)
trainDS,validDS,testDS=random_split(my_dataset2,[0.7,0.1,0.2],generator=seed) # 비율로 주기
#      학습용                           검증용                      테스트용
print(f'trainDS=>{len(trainDS)}개,validDS={len(validDS)}개,testDS={len(testDS)}개')
print('--------------------------------------------------------------------------')
print(f'Subset 속성 => indices : {trainDS.indices} \ndataset : {trainDS.dataset}')
print('-------------------------------------------------------------------------')
print(f'Subset 속성 => indices : {validDS.indices} \ndataset : {validDS.dataset}')
print('-------------------------------------------------------------------------')
print(f'Subset 속성 => indices : {testDS.indices} \ndataset : {testDS.dataset}')
# Out:
# trainDS=>105개,validDS=15개,testDS=30개
# --------------------------------------------------------------------------
# Subset 속성 => indices : [42, 95, 30, 64, 52, 35, 130, 40, 82, 17, 108, 94, 68, 97, 117, 127, 41, 44, 57, 140, 149, 32, 23, 102, 16, 113, 71, 18, 67, 66, 0, 25, 101, 112, 91, 3, 59, 116, 86, 84, 106, 142, 43, 39, 26, 98, 93, 20, 87, 19, 120, 114, 7, 63, 76, 89, 36, 45, 37, 56, 58, 122, 51, 145, 24, 21, 105, 62, 15, 11, 48, 133, 88, 50, 6, 134, 111, 8, 49, 75, 69, 124, 4, 147, 80, 100, 99, 141, 47, 107, 13, 109, 129, 28, 38, 53, 121, 5, 55, 31, 73, 74, 54, 29, 12]
# dataset : <__main__.DLDataset object at 0x0000027C37C00490>
# -------------------------------------------------------------------------
# Subset 속성 => indices : [22, 104, 81, 1, 103, 125, 85, 2, 96, 128, 27, 118, 77, 110, 146]
# dataset : <__main__.DLDataset object at 0x0000027C37C00490>
# -------------------------------------------------------------------------
# Subset 속성 => indices : [72, 139, 131, 60, 65, 92, 135, 83, 14, 34, 137, 10, 119, 9, 148, 79, 78, 70, 144, 143, 123, 115, 61, 132, 90, 46, 126, 136, 33, 138]
# dataset : <__main__.DLDataset object at 0x0000027C37C00490>

# %% [markdown]
# [3] DataLoader 생성 : 학습용,검증용,테스트용 <hr>

# %%
#DataLoader 생성
# drop_last 매개변수: 배치사이즈로 데이터셋 분리 후 남는 데이터 처리 방법 설정 [기본: False]
batch=10
trainDL=DataLoader(trainDS,batch_size=batch)
validDL=DataLoader(validDS,batch_size=batch)
testDL=DataLoader(testDS,batch_size=batch)

len(trainDL),len(validDL),len(testDL)  #105/batch   , 15/batch  ,30/batch
# Out:
# (11, 2, 3)

# %%
# Epoch 당 반복 단위
print(f'batch_size:{batch}')
print(f'trainDS=>{len(trainDS)}개,validDF=>{len(validDS)}개,testDS=>{len(testDS)}개')
print(f'trainDL=>{len(trainDL)}개,validDL=>{len(validDL)}개,testDL=>{len(testDL)}개')
# Out:
# batch_size:10
# trainDS=>105개,validDF=>15개,testDS=>30개
# trainDL=>11개,validDL=>2개,testDL=>3개

# %%
# DataLoader 속성
for _,(feature,target) in enumerate(trainDL):
    print(f'[{_} feature{feature.shape}')
    ## 로더에서 가지고온 데이터 만큼 학습 진행 => 검증 진행
# Out:
# [0 featuretorch.Size([10, 4])
# [1 featuretorch.Size([10, 4])
# [2 featuretorch.Size([10, 4])
# [3 featuretorch.Size([10, 4])
# [4 featuretorch.Size([10, 4])
# [5 featuretorch.Size([10, 4])
# [6 featuretorch.Size([10, 4])
# [7 featuretorch.Size([10, 4])
# [8 featuretorch.Size([10, 4])
# [9 featuretorch.Size([10, 4])
# [10 featuretorch.Size([5, 4])

# %% [markdown]
# [4] Model 클래스 정의: <hr> : 입/출력 피쳐수,층 수,은닉층의 노드수   <hr>
# -구조 설계
#     * 입력층 :입력 <=피쳐 갯수,iris 4개
#     * 은닉층: 마음대로 알아서 잘
#     * 출력층: 출력 <=[분류]타겟 클래스 갯수[타겟으로 정할 열의 고유값 개수] [회귀]1개

# %%
# 여기서 부터 스스로 해볼 수 있도록 한다.>.>>..

# %%
#모델 클래스 정의
#클래스명:CModel
class CModel(nn.Module):
    #구성 요소 정의 함수
    def __init__(self,in_dim=4,out_dim=3):
        super().__init__()
        self.input_layer=nn.Linear(in_dim,100) #1  피쳐 개수 4개 주입
        self.relu=nn.ReLU()
        self.hidden_layer=nn.Linear(100,27)  #2
        self.output_layer=nn.Linear(27,out_dim)    #3  마지막에 꽃종류 3개 반출
        
    #순방향 학습 진행 함수
    def forward(self,x):
        y=self.input_layer(x)   #W1X1+W2X2+....+Wnxn+b 반환(#1:100개)를 반환,아직 activation function을 덜 넣음
        y=self.relu(y)            #relu 함수 결과 100개 반환
        y=self.hidden_layer(y)      #W1X1+W2X2+....+Wnxn+b 반환(#2:27개)를 반환
        y=self.relu(y)
        y=self.output_layer(y)    #W1X1+W2X2+....+Wnxn+b 반환(#3:3개)를 반환
        return y

# %% [markdown]
# ### [5] 학습을 위한 준비:실행디바이스,모델, 최적화, 손실함수, 학습 횟수,학습 함수,평가함수,예측함수  <hr>

# %% [markdown]
# [5-1] 실행 디바이스 설정

# %%
DEVICE='cuda' if torch.cuda.is_available() else 'cpu'  #얘를 상수화 하려면 튜플(tuple)로 만들어서 표현한다.

#학습 횟수
EPOCHS=50

# %%
#형태 보기
my_dataset2.feature.shape
# Out:
# torch.Size([150, 4])

# %%
#모델 인스턴스
IN,OUT=my_dataset2.feature.shape[1],len(np.unique(targetDF))
model=CModel(IN,OUT).to(DEVICE)
print(f'IN : {IN},OUT :{OUT}')
print(model)
# Out:
# IN : 4,OUT :3
# CModel(
#   (input_layer): Linear(in_features=4, out_features=100, bias=True)
#   (relu): ReLU()
#   (hidden_layer): Linear(in_features=100, out_features=27, bias=True)
#   (output_layer): Linear(in_features=27, out_features=3, bias=True)
# )

# %%
# 손실함수
LOSS_FN=nn.CrossEntropyLoss().to(DEVICE)
# 최적화
import torch.optim as optim
optimizer=optim.Adam(model.parameters()) #여기서 lr 줄수 있음

# %% [markdown]
# ### 학습 및 검증 관련 함수 정의

# %%
# import torchmetrics.functional as metrics
# 
# 
# 
# acc=metrics.accuracy(preds,target,task='multiclass',num_classes=5)
# print(f'ACC:{acc}')

# %% [markdown]
# [5-2] 학습진행 함수

# %%
import torchmetrics.functional as metrics

# %%
def training():
    #학습 모드 => 정규화,경사하강법,드랍아웃등의 기능을 활성화
    model.train()
    #배치크기 만큼 학습 진행 및 저장
    train_loss=[]
    for cnt,(feature,target) in enumerate(trainDL):
        #배치크기만큼의 학습 데이터 준비
        feature,target=feature.to(DEVICE),target.to(DEVICE)
        target=target.squeeze()  #차원 축소
        
        #학습
        pre_target=model(feature)
        print(f'pre_target => {pre_target.shape},{pre_target.ndim}D')
        print(f'target => {target.shape},{target.ndim}D')
        #손실계산
        loss=LOSS_FN(pre_target,target)
        train_loss.append(loss)
   
        #w,b 업데이트
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        #배치 단위 학습 진행 메시지 출력
        # print(f'[Train {cnt} batch LOSS] ==> {loss}')
        
    # 에포크 단위 진행 메시지 출력
    acc=metrics.accuracy(pre_target,target,task='multiclass',num_classes=3)  #num_classes 이거는 3
    print(f'[Train loss] ==> {loss} [ACC] ==> {acc} \n\n')
    
    return train_loss

# %%
for cnt,(feature,target) in enumerate(trainDL):
        print(cnt,feature,target)
# Out:
# 0 tensor([[4.4000, 3.2000, 1.3000, 0.2000],
#         [5.7000, 3.0000, 4.2000, 1.2000],
#         [4.8000, 3.1000, 1.6000, 0.2000],
#         [5.6000, 2.9000, 3.6000, 1.3000],
#         [6.9000, 3.1000, 4.9000, 1.5000],
#         [5.0000, 3.2000, 1.2000, 0.2000],
#         [7.4000, 2.8000, 6.1000, 1.9000],
#         [5.0000, 3.5000, 1.3000, 0.3000],
#         [5.8000, 2.7000, 3.9000, 1.2000],
#         [5.1000, 3.5000, 1.4000, 0.3000]]) tensor([[0],
#         [1],
#         [0],
#         [1],
#         [1],
#         [0],
#         [2],
#         [0],
#         [1],
#         [0]])
# 1 tensor([[6.7000, 2.5000, 5.8000, 1.8000],
#         [5.6000, 2.7000, 4.2000, 1.3000],
#         [6.2000, 2.2000, 4.5000, 1.5000],
#         [6.2000, 2.9000, 4.3000, 1.3000],
#         [7.7000, 3.8000, 6.7000, 2.2000],
#         [6.1000, 3.0000, 4.9000, 1.8000],
#         [4.5000, 2.3000, 1.3000, 0.3000],
#         [5.1000, 3.8000, 1.9000, 0.4000],
#         [4.9000, 2.4000, 3.3000, 1.0000],
#         [6.7000, 3.1000, 5.6000, 2.4000]]) tensor([[2],
#         [1],
#         [1],
#         [1],
#         [2],
#         [2],
#         [0],
#         [0],
#         [1],
#         [2]])
# 2 tensor([[5.9000, 3.0000, 5.1000, 1.8000],
#         [5.2000, 4.1000, 1.5000, 0.1000],
#         [5.1000, 3.3000, 1.7000, 0.5000],
#         [7.1000, 3.0000, 5.9000, 2.1000],
#         [5.4000, 3.9000, 1.3000, 0.4000],
#         [5.7000, 2.5000, 5.0000, 2.0000],
#         [6.1000, 2.8000, 4.0000, 1.3000],
#         [5.7000, 3.8000, 1.7000, 0.3000],
#         [5.8000, 2.7000, 4.1000, 1.0000],
#         [5.6000, 3.0000, 4.5000, 1.5000]]) tensor([[2],
#         [0],
#         [0],
#         [2],
#         [0],
#         [2],
#         [1],
#         [0],
#         [1],
#         [1]])
# 3 tensor([[5.1000, 3.5000, 1.4000, 0.2000],
#         [5.0000, 3.0000, 1.6000, 0.2000],
#         [5.8000, 2.7000, 5.1000, 1.9000],
#         [6.8000, 3.0000, 5.5000, 2.1000],
#         [6.1000, 3.0000, 4.6000, 1.4000],
#         [4.6000, 3.1000, 1.5000, 0.2000],
#         [5.2000, 2.7000, 3.9000, 1.4000],
#         [6.5000, 3.0000, 5.5000, 1.8000],
#         [6.7000, 3.1000, 4.7000, 1.5000],
#         [5.4000, 3.0000, 4.5000, 1.5000]]) tensor([[0],
#         [0],
#         [2],
#         [2],
#         [1],
#         [0],
#         [1],
#         [2],
#         [1],
#         [1]])
# 4 tensor([[4.9000, 2.5000, 4.5000, 1.7000],
#         [5.8000, 2.7000, 5.1000, 1.9000],
#         [5.0000, 3.5000, 1.6000, 0.6000],
#         [5.1000, 3.4000, 1.5000, 0.2000],
#         [5.0000, 3.4000, 1.6000, 0.4000],
#         [5.1000, 2.5000, 3.0000, 1.1000],
#         [5.0000, 2.3000, 3.3000, 1.0000],
#         [5.4000, 3.4000, 1.7000, 0.2000],
#         [6.3000, 2.3000, 4.4000, 1.3000],
#         [5.1000, 3.8000, 1.5000, 0.3000]]) tensor([[2],
#         [2],
#         [0],
#         [0],
#         [0],
#         [1],
#         [1],
#         [0],
#         [1],
#         [0]])
# 5 tensor([[6.9000, 3.2000, 5.7000, 2.3000],
#         [5.8000, 2.8000, 5.1000, 2.4000],
#         [5.0000, 3.4000, 1.5000, 0.2000],
#         [6.1000, 2.9000, 4.7000, 1.4000],
#         [6.8000, 2.8000, 4.8000, 1.4000],
#         [5.5000, 2.5000, 4.0000, 1.3000],
#         [5.5000, 3.5000, 1.3000, 0.2000],
#         [4.8000, 3.0000, 1.4000, 0.3000],
#         [4.9000, 3.1000, 1.5000, 0.1000],
#         [6.3000, 3.3000, 4.7000, 1.6000]]) tensor([[2],
#         [2],
#         [0],
#         [1],
#         [1],
#         [1],
#         [0],
#         [0],
#         [0],
#         [1]])
# 6 tensor([[6.6000, 2.9000, 4.6000, 1.3000],
#         [7.7000, 2.8000, 6.7000, 2.0000],
#         [6.4000, 3.2000, 4.5000, 1.5000],
#         [6.7000, 3.0000, 5.2000, 2.3000],
#         [4.8000, 3.4000, 1.9000, 0.2000],
#         [5.1000, 3.7000, 1.5000, 0.4000],
#         [7.6000, 3.0000, 6.6000, 2.1000],
#         [6.0000, 2.2000, 4.0000, 1.0000],
#         [5.7000, 4.4000, 1.5000, 0.4000],
#         [4.8000, 3.4000, 1.6000, 0.2000]]) tensor([[1],
#         [2],
#         [1],
#         [2],
#         [0],
#         [0],
#         [2],
#         [1],
#         [0],
#         [0]])
# 7 tensor([[5.3000, 3.7000, 1.5000, 0.2000],
#         [6.3000, 2.8000, 5.1000, 1.5000],
#         [5.6000, 3.0000, 4.1000, 1.3000],
#         [7.0000, 3.2000, 4.7000, 1.4000],
#         [4.6000, 3.4000, 1.4000, 0.3000],
#         [6.1000, 2.6000, 5.6000, 1.4000],
#         [6.4000, 2.7000, 5.3000, 1.9000],
#         [4.4000, 2.9000, 1.4000, 0.2000],
#         [5.0000, 3.3000, 1.4000, 0.2000],
#         [6.6000, 3.0000, 4.4000, 1.4000]]) tensor([[0],
#         [2],
#         [1],
#         [1],
#         [0],
#         [2],
#         [2],
#         [0],
#         [0],
#         [1]])
# 8 tensor([[5.6000, 2.5000, 3.9000, 1.1000],
#         [6.7000, 3.3000, 5.7000, 2.1000],
#         [5.0000, 3.6000, 1.4000, 0.2000],
#         [6.5000, 3.0000, 5.2000, 2.0000],
#         [5.5000, 2.4000, 3.8000, 1.1000],
#         [6.3000, 3.3000, 6.0000, 2.5000],
#         [5.7000, 2.8000, 4.1000, 1.3000],
#         [6.9000, 3.1000, 5.1000, 2.3000],
#         [4.6000, 3.2000, 1.4000, 0.2000],
#         [7.3000, 2.9000, 6.3000, 1.8000]]) tensor([[1],
#         [2],
#         [0],
#         [2],
#         [1],
#         [2],
#         [1],
#         [2],
#         [0],
#         [2]])
# 9 tensor([[4.3000, 3.0000, 1.1000, 0.1000],
#         [7.2000, 3.6000, 6.1000, 2.5000],
#         [7.2000, 3.0000, 5.8000, 1.6000],
#         [5.2000, 3.4000, 1.4000, 0.2000],
#         [4.4000, 3.0000, 1.3000, 0.2000],
#         [5.5000, 2.3000, 4.0000, 1.3000],
#         [5.6000, 2.8000, 4.9000, 2.0000],
#         [5.4000, 3.9000, 1.7000, 0.4000],
#         [5.7000, 2.8000, 4.5000, 1.3000],
#         [5.4000, 3.4000, 1.5000, 0.4000]]) tensor([[0],
#         [2],
#         [2],
#         [0],
#         [0],
#         [1],
#         [2],
#         [0],
#         [1],
#         [0]])
# 10 tensor([[6.1000, 2.8000, 4.7000, 1.2000],
#         [6.4000, 2.9000, 4.3000, 1.3000],
#         [6.5000, 2.8000, 4.6000, 1.5000],
#         [4.7000, 3.2000, 1.6000, 0.2000],
#         [4.8000, 3.0000, 1.4000, 0.1000]]) tensor([[1],
#         [1],
#         [1],
#         [0],
#         [0]])

# %% [markdown]
# [5-3] 검증 및 평가 진행함수

# %%
# 매개변수 dataLoader : 검증 또는 테스트 데이터셋에 대한 Loader
def testing(dataLoader):
    #추론 모드 => 정규화,경사하강법,드랍아웃등의 기능을 비활성화
    model.eval()
    #배치크기 만큼 학습 진행 및 저장
    with torch.no_grad():
        #배치크기 만큼 학습 진행 및 저장
        val_loss=[]
        for cnt,(feature,target) in enumerate(dataLoader):
            #배치크기만큼의 학습 데이터 준비
            feature,target=feature.to(DEVICE),target.to(DEVICE)
            target=target.squeeze()  #차원 축소
            
            #학습
            pre_target=model(feature)
            print(f'pre_target => {pre_target.shape},{pre_target.ndim}D')
            print(f'target => {target.shape},{target.ndim}D')
            #손실계산
            loss=LOSS_FN(pre_target,target)
            val_loss.append(loss)
       
            
            
            
        # 에포크 단위 진행 메시지 출력
        acc=metrics.accuracy(pre_target,target,task='multiclass',num_classes=3)  #num_classes 이거는 3
        print(f'[Valid loss] ==> {loss} [Valid loss] ==> {acc} \n\n')
        
        return val_loss

# %% [markdown]
# [5-4] 예측 함수

# %%
def predict():
    pass

# %% [markdown]
# ### [6] 학습 진행 <hr>

# %%
### ===>지정된 횟수 만큼 처음부터~ 끝까지 학습 및 검증 진행
### ===>목표:최적(Error 최소화)의 W,b를 가진 모델 완성
### ===>
for eps in range(1,EPOCHS+1):
    # 학습 함수
    train_loss=training()
    #검증 함수
    valid_loss=testing(validDL)  #validDL 넣어야 돌아간다
    print(f'[{eps}/{EPOCHS}]{sum(train_loss)/len(train_loss)},\
          VALID:{sum(valid_loss)/len(valid_loss)}\n')
    #조기종료 기능 ==> 조건 : val_loss가 지정된 횟수(예:5)이상 개선이 안되면 학습 종료
# Out:
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Train loss] ==> 0.005419963970780373 [ACC] ==> 1.0
#
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Valid loss] ==> 0.07309480011463165 [ACC] ==> 1.0
#
#
# [1/50]0.02635442465543747,          VALID:0.0379570908844471
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Train loss] ==> 0.005296549294143915 [ACC] ==> 1.0
#
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Valid loss] ==> 0.07257018238306046 [ACC] ==> 1.0
#
#
# [2/50]0.026116199791431427,          VALID:0.03765270113945007
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Train loss] ==> 0.005179253872483969 [ACC] ==> 1.0
#
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Valid loss] ==> 0.07204701751470566 [ACC] ==> 1.0
#
#
# [3/50]0.025874705985188484,          VALID:0.03735018149018288
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Train loss] ==> 0.005062556359916925 [ACC] ==> 1.0
#
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Valid loss] ==> 0.07153447717428207 [ACC] ==> 1.0
#
#
# [4/50]0.025641657412052155,          VALID:0.03705452010035515
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Train loss] ==> 0.004948013462126255 [ACC] ==> 1.0
#
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Valid loss] ==> 0.07102970778942108 [ACC] ==> 1.0
#
#
# [5/50]0.025415312498807907,          VALID:0.036764390766620636
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Train loss] ==> 0.004841765854507685 [ACC] ==> 1.0
#
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Valid loss] ==> 0.07052017003297806 [ACC] ==> 1.0
#
#
# [6/50]0.025181712582707405,          VALID:0.03647257760167122
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Train loss] ==> 0.004732266068458557 [ACC] ==> 1.0
#
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Valid loss] ==> 0.0700278952717781 [ACC] ==> 1.0
#
#
# [7/50]0.024965129792690277,          VALID:0.03619103878736496
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Train loss] ==> 0.00462932838127017 [ACC] ==> 1.0
#
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Valid loss] ==> 0.06953294575214386 [ACC] ==> 1.0
#
#
# [8/50]0.02474343776702881,          VALID:0.0359090119600296
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Train loss] ==> 0.00452664727345109 [ACC] ==> 1.0
#
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Valid loss] ==> 0.06904859095811844 [ACC] ==> 1.0
#
#
# [9/50]0.024530159309506416,          VALID:0.03563361614942551
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Train loss] ==> 0.004427661187946796 [ACC] ==> 1.0
#
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Valid loss] ==> 0.06856611371040344 [ACC] ==> 1.0
#
#
# [10/50]0.024319889023900032,          VALID:0.03536015376448631
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Train loss] ==> 0.00433145510032773 [ACC] ==> 1.0
#
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Valid loss] ==> 0.06808815151453018 [ACC] ==> 1.0
#
#
# [11/50]0.02411302924156189,          VALID:0.035089995712041855
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Train loss] ==> 0.004237110260874033 [ACC] ==> 1.0
#
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Valid loss] ==> 0.06761658191680908 [ACC] ==> 1.0
#
#
# [12/50]0.02390800043940544,          VALID:0.03482411429286003
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Train loss] ==> 0.00414498383179307 [ACC] ==> 1.0
#
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Valid loss] ==> 0.06714902073144913 [ACC] ==> 1.0
#
#
# [13/50]0.02370939403772354,          VALID:0.03456120565533638
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Train loss] ==> 0.004054580815136433 [ACC] ==> 1.0
#
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Valid loss] ==> 0.06668809801340103 [ACC] ==> 1.0
#
#
# [14/50]0.023515738546848297,          VALID:0.03430280461907387
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Train loss] ==> 0.003969132900238037 [ACC] ==> 1.0
#
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Valid loss] ==> 0.06622549891471863 [ACC] ==> 1.0
#
#
# [15/50]0.02331553027033806,          VALID:0.03404416888952255
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Train loss] ==> 0.0038824877701699734 [ACC] ==> 1.0
#
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Valid loss] ==> 0.06577357649803162 [ACC] ==> 1.0
#
#
# [16/50]0.023129742592573166,          VALID:0.03379193693399429
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Train loss] ==> 0.003800117876380682 [ACC] ==> 1.0
#
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Valid loss] ==> 0.06532184034585953 [ACC] ==> 1.0
#
#
# [17/50]0.022938402369618416,          VALID:0.03354046493768692
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Train loss] ==> 0.0037181333173066378 [ACC] ==> 1.0
#
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Valid loss] ==> 0.0648767352104187 [ACC] ==> 1.0
#
#
# [18/50]0.02275768481194973,          VALID:0.033293217420578
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Train loss] ==> 0.0036401438992470503 [ACC] ==> 1.0
#
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Valid loss] ==> 0.06443120539188385 [ACC] ==> 1.0
#
#
# [19/50]0.022574128583073616,          VALID:0.033046457916498184
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Train loss] ==> 0.0035621393471956253 [ACC] ==> 1.0
#
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Valid loss] ==> 0.06399457156658173 [ACC] ==> 1.0
#
#
# [20/50]0.022396862506866455,          VALID:0.03280505910515785
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Train loss] ==> 0.00348714180290699 [ACC] ==> 1.0
#
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Valid loss] ==> 0.06355812400579453 [ACC] ==> 1.0
#
#
# [21/50]0.022219868376851082,          VALID:0.032564371824264526
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Train loss] ==> 0.0034129805862903595 [ACC] ==> 1.0
#
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Valid loss] ==> 0.06312866508960724 [ACC] ==> 1.0
#
#
# [22/50]0.022047294303774834,          VALID:0.03232797980308533
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Train loss] ==> 0.0033412626944482327 [ACC] ==> 1.0
#
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Valid loss] ==> 0.0626998171210289 [ACC] ==> 1.0
#
#
# [23/50]0.021877076476812363,          VALID:0.03209248557686806
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Train loss] ==> 0.003270902205258608 [ACC] ==> 1.0
#
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Valid loss] ==> 0.062276650220155716 [ACC] ==> 1.0
#
#
# [24/50]0.021707940846681595,          VALID:0.03186053782701492
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Train loss] ==> 0.003202065359801054 [ACC] ==> 1.0
#
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Valid loss] ==> 0.06185559555888176 [ACC] ==> 1.0
#
#
# [25/50]0.02154490165412426,          VALID:0.031630247831344604
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Train loss] ==> 0.0031358625274151564 [ACC] ==> 1.0
#
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Valid loss] ==> 0.061435382813215256 [ACC] ==> 1.0
#
#
# [26/50]0.021380813792347908,          VALID:0.03140084818005562
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Train loss] ==> 0.00306950556114316 [ACC] ==> 1.0
#
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Valid loss] ==> 0.061022885143756866 [ACC] ==> 1.0
#
#
# [27/50]0.02122199349105358,          VALID:0.031175993382930756
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Train loss] ==> 0.003005528124049306 [ACC] ==> 1.0
#
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Valid loss] ==> 0.06061279773712158 [ACC] ==> 1.0
#
#
# [28/50]0.021060489118099213,          VALID:0.030952950939536095
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Train loss] ==> 0.0029423912055790424 [ACC] ==> 1.0
#
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Valid loss] ==> 0.060205381363630295 [ACC] ==> 1.0
#
#
# [29/50]0.020908525213599205,          VALID:0.030731769278645515
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Train loss] ==> 0.00288246083073318 [ACC] ==> 1.0
#
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Valid loss] ==> 0.05979692190885544 [ACC] ==> 1.0
#
#
# [30/50]0.020752867683768272,          VALID:0.030510462820529938
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Train loss] ==> 0.002822381444275379 [ACC] ==> 1.0
#
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Valid loss] ==> 0.059396952390670776 [ACC] ==> 1.0
#
#
# [31/50]0.020602412521839142,          VALID:0.030294116586446762
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Train loss] ==> 0.002764113713055849 [ACC] ==> 1.0
#
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Valid loss] ==> 0.0589987114071846 [ACC] ==> 1.0
#
#
# [32/50]0.02044898085296154,          VALID:0.030079064890742302
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Train loss] ==> 0.002706547500565648 [ACC] ==> 1.0
#
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Valid loss] ==> 0.05860345438122749 [ACC] ==> 1.0
#
#
# [33/50]0.020307287573814392,          VALID:0.02986619994044304
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Train loss] ==> 0.0026521680410951376 [ACC] ==> 1.0
#
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Valid loss] ==> 0.05820613354444504 [ACC] ==> 1.0
#
#
# [34/50]0.020159441977739334,          VALID:0.029652616009116173
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Train loss] ==> 0.0025971424765884876 [ACC] ==> 1.0
#
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Valid loss] ==> 0.05781816318631172 [ACC] ==> 1.0
#
#
# [35/50]0.020017119124531746,          VALID:0.02944430336356163
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Train loss] ==> 0.002543861046433449 [ACC] ==> 1.0
#
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Valid loss] ==> 0.057431794703006744 [ACC] ==> 1.0
#
#
# [36/50]0.01987215131521225,          VALID:0.029237177222967148
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Train loss] ==> 0.002491449238732457 [ACC] ==> 1.0
#
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Valid loss] ==> 0.057047344744205475 [ACC] ==> 1.0
#
#
# [37/50]0.019738299772143364,          VALID:0.029031407088041306
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Train loss] ==> 0.0024420381523668766 [ACC] ==> 1.0
#
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Valid loss] ==> 0.056660689413547516 [ACC] ==> 1.0
#
#
# [38/50]0.019597886130213737,          VALID:0.02882484160363674
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Train loss] ==> 0.0023918631486594677 [ACC] ==> 1.0
#
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Valid loss] ==> 0.05628364160656929 [ACC] ==> 1.0
#
#
# [39/50]0.019463099539279938,          VALID:0.028623588383197784
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Train loss] ==> 0.002343221101909876 [ACC] ==> 1.0
#
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Valid loss] ==> 0.05590816214680672 [ACC] ==> 1.0
#
#
# [40/50]0.019325122237205505,          VALID:0.02842346765100956
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Train loss] ==> 0.0022954982705414295 [ACC] ==> 1.0
#
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Valid loss] ==> 0.055534083396196365 [ACC] ==> 1.0
#
#
# [41/50]0.019197970628738403,          VALID:0.02822437882423401
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Train loss] ==> 0.002250541001558304 [ACC] ==> 1.0
#
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Valid loss] ==> 0.055157460272312164 [ACC] ==> 1.0
#
#
# [42/50]0.019064083695411682,          VALID:0.028024280443787575
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Train loss] ==> 0.0022045604418963194 [ACC] ==> 1.0
#
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Valid loss] ==> 0.05479113385081291 [ACC] ==> 1.0
#
#
# [43/50]0.018937192857265472,          VALID:0.027829814702272415
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Train loss] ==> 0.002160208998247981 [ACC] ==> 1.0
#
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Valid loss] ==> 0.05442564934492111 [ACC] ==> 1.0
#
#
# [44/50]0.01880519837141037,          VALID:0.027636036276817322
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Train loss] ==> 0.002116659190505743 [ACC] ==> 1.0
#
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Valid loss] ==> 0.054061125963926315 [ACC] ==> 1.0
#
#
# [45/50]0.018683265894651413,          VALID:0.027443040162324905
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Train loss] ==> 0.0020748586393892765 [ACC] ==> 1.0
#
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Valid loss] ==> 0.0536993145942688 [ACC] ==> 1.0
#
#
# [46/50]0.01855294406414032,          VALID:0.02725168503820896
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Train loss] ==> 0.0020329831168055534 [ACC] ==> 1.0
#
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Valid loss] ==> 0.05334019660949707 [ACC] ==> 1.0
#
#
# [47/50]0.018435999751091003,          VALID:0.027062000706791878
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Train loss] ==> 0.0019932601135224104 [ACC] ==> 1.0
#
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Valid loss] ==> 0.05298225209116936 [ACC] ==> 1.0
#
#
# [48/50]0.018307866528630257,          VALID:0.0268731489777565
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Train loss] ==> 0.0019531783182173967 [ACC] ==> 1.0
#
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Valid loss] ==> 0.05262817069888115 [ACC] ==> 1.0
#
#
# [49/50]0.018193261697888374,          VALID:0.02668655291199684
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Train loss] ==> 0.0019150602165609598 [ACC] ==> 1.0
#
#
# pre_target => torch.Size([10, 3]),2D
# target => torch.Size([10]),1D
# pre_target => torch.Size([5, 3]),2D
# target => torch.Size([5]),1D
# [Valid loss] ==> 0.05227543041110039 [ACC] ==> 1.0
#
#
# [50/50]0.018069321289658546,          VALID:0.026500822976231575

# %% [markdown]
# [7] 테스트 진행 <hr>

# %%
valid_loss=testing(testDL)
